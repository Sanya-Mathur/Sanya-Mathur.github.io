# %% [markdown]
# <a href="https://colab.research.google.com/github/SanyaMathur0411/SanyaMathur0411.github.io/blob/main/Pandas_and_Dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
data = { "calories": [420, 380, 390], "duration": [50, 40, 45] }  #DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(df.loc[0])  #Locate Row 0
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
print(df.loc[[0, 1]])  #Locate Row 0 and 1
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
import pandas as pd
data = { "calories": [420, 380, 390], "duration": [50, 40, 45] }  #Named Indexes
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
print(df.loc["day2"])  #Locating Named Indexes
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('data.csv')   #Load files into a DataFrame
print(df)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)   #Create a simple Pandas series from a list
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
print(myvar[0])   #Labels
# Out:
# 1

# %%
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])   #Create your own labels
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["y"])  #Accessing item using label
# Out:
# 7

# %%
import pandas as pd
calories = {"day1": 420, "day2": 380, "day3": 390}  #Create a simple Pandas Series from a dictionary
myvar = pd.Series(calories)                         #The keys of the dictionary become labels
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
import pandas as pd
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories, index = ["day1", "day2"])    #Create a Series using only data from "day1" and "day2"
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
data = {
"calories": [420, 380, 390],              #Create a DataFrame from two Series
"duration": [50, 40, 45]
}
myvar = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
import pandas as pd
data = pd.Series([10, 20, 38, 40, 50])  #Accessing-Integer Indexing
print(data[2])
# Out:
# 38

# %%
import pandas as pd
data = pd.Series([10, 20, 28, 40, 50], index=['A', 'B', 'C', 'D', 'E'])  #Using Custom Index Label
print(data['C'])
# Out:
# 28

# %%
import pandas as pd
data = {'Name': ['John', 'Anna', 'Peter'], 'Age': [28, 24, 22]}  #Using Multiple Column Names
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   24
# 2  Peter   22

# %%
import pandas as pd
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata','Mahindra', 'Maruti', 'Hyundai', 'Renault',
'Tata', 'Maruti'], 'Year': [2012, 2014, 2011, 2015, 2012, 2016, 2014, 2018, 2019],
'Kms Driven': [50000, 30000, 60000, 25000, 10000, 46000, 31000, 15000, 12000],
'City': ['Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Chennai', 'Ghaziabad'],
'Mileage': [28, 27, 25, 26, 28, 29, 24, 21, 24]})
print(data)
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(data.loc[(data.Brand == 'Maruti') & (data.Mileage > 25)])    #Selecting Data According to Some Conditions
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       28
# 4  Maruti  2012       10000   Mumbai       28

# %%
print(data.loc[2: 5])    #Selecting a Range of Rows From the DataFrame
# Out:
#       Brand  Year  Kms Driven    City  Mileage
# 2      Tata  2011       60000  Mumbai       25
# 3  Mahindra  2015       25000   Delhi       26
# 4    Maruti  2012       10000  Mumbai       28
# 5   Hyundai  2016       46000   Delhi       29

# %%
data.loc[(data.Year < 2015), ['Mileage']] = 22  #Updating the Value of Any Column
print(data)
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       22
# 1   Hyundai  2014       30000      Delhi       22
# 2      Tata  2011       60000     Mumbai       22
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       22
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       22
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(data.iloc[[0, 2, 4, 7]])  #Selecting Rows Using Integer Indices
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       22
# 2    Tata  2011       60000   Mumbai       22
# 4  Maruti  2012       10000   Mumbai       22
# 7    Tata  2018       15000  Chennai       21

# %%
print(data.iloc[1: 5, 2: 5])     #Selecting a Range of Columns and Rows Simultaneously
# Out:
#    Kms Driven    City  Mileage
# 1       30000   Delhi       22
# 2       60000  Mumbai       22
# 3       25000   Delhi       26
# 4       10000  Mumbai       22

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
position = 2
label = 'Brand'
output = data.at[position, label]
print(output)
# Out:
# Tata

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
column = 3
row = 2
output = data.iat[row, column]
print(output)
# Out:
# Mumbai

# %%
import pandas as pd
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
		'Height': [5.1, 6.2, 5.1, 5.2],
		'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}            #Adding a Column
df = pd.DataFrame(data)
address = ['Delhi', 'Bangalore', 'Chennai', 'Patna']
df['Address'] = address
print(df)
# Out:
#      Name  Height Qualification    Address
# 0     Jai     5.1           Msc      Delhi
# 1  Princi     6.2            MA  Bangalore
# 2  Gaurav     5.1           Msc    Chennai
# 3    Anuj     5.2           Msc      Patna

# %%
import pandas as pd
series1 = pd.Series([1, 2, 3, 4, 5])        #Addition of 2 series
series2 = pd.Series([6, 7, 8, 9, 10])
series3 = series1 + series2
print(series3)
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %%
import pandas as pd
series1 = pd.Series([1, 2, 3, 4, 5])
series2 = pd.Series([6, 7, 8, 9, 10])   #Subtraction of 2 series
series3 = series1 - series2
print(series3)
# Out:
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64

# %%
import pandas as pd
series1 = pd.Series([1, 2, 3, 4, 5])
series2 = pd.Series([6, 7, 8, 9, 10])   #Multiplication of 2 series
series3 = series1 * series2
print(series3)
# Out:
# 0     6
# 1    14
# 2    24
# 3    36
# 4    50
# dtype: int64

# %%
import pandas as pd
series1 = pd.Series([1, 2, 3, 4, 5])
series2 = pd.Series([6, 7, 8, 9, 10])   #Division of 2 series
series3 = series1 / series2
print(series3)
# Out:
# 0    0.166667
# 1    0.285714
# 2    0.375000
# 3    0.444444
# 4    0.500000
# dtype: float64

# %%
import pandas as pd
data = {
'Name': ['Alice', 'Bob', 'Charlie', 'David'],
'Age': [25, 32, 30, 29],
'Score': [85, 92, 88, 75]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   32     92
# 2  Charlie   30     88
# 3    David   29     75

# %%
filtered_df = df[(df['Age'] > 30) & (df['Score'] > 80)]   #AND Operation (&)
print(filtered_df)
# Out:
#   Name  Age  Score
# 1  Bob   32     92

# %%
filtered_df_or = df[(df['Age'] > 30) | (df['Score'] > 80)]  #OR Operation (|)
print(filtered_df_or)
# Out:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   32     92
# 2  Charlie   30     88

# %%
filtered_df_not = df[~(df['Score'] > 80)]   #NOT Operation (~)
print(filtered_df_not)
# Out:
#     Name  Age  Score
# 3  David   29     75

# %%
import pandas as pd
data = {
"name": ["Sally", "Mary", "John"],
"age": [50, 40, 30],
"qualified": [True, False, False]            #DataFrame Filter() Method
}
df = pd.DataFrame(data)
newdf = df.filter(items=["name", "age"])
print(newdf)
# Out:
#     name  age
# 0  Sally   50
# 1   Mary   40
# 2   John   30

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon', 'Parrot', 'Parrot'],
'Max Speed': [380., 370., 24., 26.]})
print(df.groupby(['Animal']).mean())
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
import pandas as pd
l = [[1, 2, 3], [1, None, 4], [2, 1, 3], [1, 2, 2]]
df = pd.DataFrame(l, columns=["a", "b", "c"])
print(df)
print("Groupby operation")
print(df.groupby(by=["b"]).sum())
# Out:
#    a    b  c
# 0  1  2.0  3
# 1  1  NaN  4
# 2  2  1.0  3
# 3  1  2.0  2
# Groupby operation
#      a  c
# b
# 1.0  2  3
# 2.0  2  5

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'A': ['John', 'Boby', 'Mina', 'Peter', 'Nicky'],
'B': ['Masters', 'Graduate', 'Graduate', 'Masters', 'Graduate'],
'C': [27, 23, 21, 23, 24]})
print(df)
# Out:
#        A         B   C
# 0   John   Masters  27
# 1   Boby  Graduate  23
# 2   Mina  Graduate  21
# 3  Peter   Masters  23
# 4  Nicky  Graduate  24

# %%
table = pd.pivot_table(df, index =['A', 'B'])
print(table)
# Out:
#                    C
# A     B
# Boby  Graduate  23.0
# John  Masters   27.0
# Mina  Graduate  21.0
# Nicky Graduate  24.0
# Peter Masters   23.0

# %%
table = pd.pivot_table(df, values ='A', index =['B', 'C'], columns =['B'], aggfunc = np.sum)
print(table)
# Out:
# B           Graduate Masters
# B        C
# Graduate 21     Mina     NaN
#          23     Boby     NaN
#          24    Nicky     NaN
# Masters  23      NaN   Peter
#          27      NaN    John
# <ipython-input-40-8226ca98b5df>:1: FutureWarning: The provided callable <function sum at 0x7a6c35bdc0d0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table = pd.pivot_table(df, values ='A', index =['B', 'C'], columns =['B'], aggfunc = np.sum)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.DataFrame({
'gender': ['male', 'male', 'female', 'female', 'male', 'female', 'male', 'female'],
'education_level': ['high school', 'college', 'college', 'graduate', 'high school', 'graduate', 'college',
'graduate'],
'score': [75, 82, 88, 95, 69, 92, 78, 85]
})
ct = pd.crosstab(df['gender'], df['education_level'])
print(ct)
# Out:
# education_level  college  graduate  high school
# gender
# female                 1         3            0
# male                   2         0            2

# %%
import pandas
import numpy
a = numpy.array(["foo", "foo", "foo", "foo", "bar", "bar", "bar", "bar", "foo", "foo", "foo"],
dtype=object)
b = numpy.array(["one", "one", "one", "two", "one", "one", "one", "two", "two", "two", "one"],
dtype=object)
c = numpy.array(["dull", "dull", "shiny", "dull", "dull", "shiny", "shiny", "dull", "shiny",
"shiny", "shiny"], dtype=object)
pandas.crosstab(a, [b, c], rownames=['a'], colnames=['b', 'c'])
# Out:
# b    one        two
# c   dull shiny dull shiny
# a
# bar    1     2    1     0
# foo    2     2    1     2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
dict = {'First Score':[100, 90, np.nan, 95],'Second Score': [30, 45, 56, np.nan],'Third Score':[np.nan,
40, 80, 98]}                      #isnull()
df = pd.DataFrame(dict)
df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
df.notnull()      #notnull()
# Out:
#    First Score  Second Score  Third Score
# 0         True          True        False
# 1         True          True         True
# 2        False          True         True
# 3         True         False         True

# %%
df.dropna()       #dropna()
# Out:
#    First Score  Second Score  Third Score
# 1         90.0          45.0         40.0

# %%
df.fillna(0)    #fillna()
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %%
df.fillna(method ='pad')   #Filling null values with the previous ones:
# Out:
# <ipython-input-47-cb689811ebc0>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method ='pad')   #Filling null values with the previous ones:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
df.fillna(method ='bfill')   #Filling null values with the next ones:
# Out:
# <ipython-input-48-3b9c160734e3>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method ='bfill')   #Filling null values with the next ones:
#    First Score  Second Score  Third Score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df.replace(to_replace = np.nan, value = -99)   #replace()
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0        -99.0
# 1         90.0          45.0         40.0
# 2        -99.0          56.0         80.0
# 3         95.0         -99.0         98.0

# %%
df.interpolate(method ='linear', limit_direction ='forward')  #interpolate()
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         92.5          56.0         80.0
# 3         95.0          56.0         98.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
print(pd.date_range('1/1/2011', periods=5))
# Out:
# DatetimeIndex(['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04',
#                '2011-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
print(pd.date_range('1/1/2011', periods=5,freq='M'))  #Change the Date Frequency
# Out:
# DatetimeIndex(['2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30',
#                '2011-05-31'],
#               dtype='datetime64[ns]', freq='ME')
# <ipython-input-54-21dce5bfa322>:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   print(pd.date_range('1/1/2011', periods=5,freq='M'))  #Change the Date Frequency

# %%
import pandas as pd
print(pd.bdate_range(start='1/1/2018', end='1/08/2018'))
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-08'],
#               dtype='datetime64[ns]', freq='B')

# %%
import pandas as pd
td = pd.Timedelta('3 days 06:05:01.000000111')   #Time Delta
print(td)
print(td.seconds)
# Out:
# 3 days 06:05:01.000000111
# 21901

# %%
import pandas as pd
td = pd.Timedelta('7 days 15 min 3 s')   #Manipulating and Accessing Components of Pandas Timedelta
print(td)
print(td.seconds)
# Out:
# 7 days 00:15:03
# 903

# %%
import pandas as pd
import datetime
td = pd.Timedelta(133, unit='s')    #Creating and Accessing Pandas Timedelta with Specified Units
print(td)
print(td.seconds)
# Out:
# 0 days 00:02:13
# 133

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import time
import numpy
import array
# 8 bytes size int
a = array.array('q')
for i in range(100000):
    a.append(i);
b = array.array('q')
for i in range(100000, 200000):
    b.append(i)
# classic dot product of vectors implementation
tic = time.process_time()
dot = 0.0;
for i in range(len(a)):
    dot += a[i] * b[i]
toc = time.process_time()
print("dot_product = "+ str(dot));
print("Computation time = " + str(1000*(toc - tic )) + "ms")
n_tic = time.process_time()
n_dot_product = numpy.dot(a, b)
n_toc = time.process_time()
print("\nn_dot_product = "+str(n_dot_product))
print("Computation time = "+str(1000*(n_toc - n_tic ))+"ms")
# Out:
# dot_product = 833323333350000.0
# Computation time = 38.74283599999728ms
#
# n_dot_product = 833323333350000
# Computation time = 1.7927900000032082ms

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import time
import numpy
import array
a = array.array('i')
for i in range(200):
  a.append(i);
b = array.array('i')
for i in range(200, 400):
  b.append(i)
tic = time.process_time()
outer_product = numpy.zeros((200, 200))
for i in range(len(a)):
  for j in range(len(b)):
     outer_product[i][j]= a[i]*b[j]
toc = time.process_time()
print("outer_product = "+ str(outer_product));
print("Computation time = "+str(1000*(toc - tic ))+"ms")
n_tic = time.process_time()
outer_product = numpy.outer(a, b)
n_toc = time.process_time()
print("outer_product = "+str(outer_product));
print("\nComputation time = "+str(1000*(n_toc - n_tic ))+"ms")
# Out:
# outer_product = [[    0.     0.     0. ...     0.     0.     0.]
#  [  200.   201.   202. ...   397.   398.   399.]
#  [  400.   402.   404. ...   794.   796.   798.]
#  ...
#  [39400. 39597. 39794. ... 78209. 78406. 78603.]
#  [39600. 39798. 39996. ... 78606. 78804. 79002.]
#  [39800. 39999. 40198. ... 79003. 79202. 79401.]]
# Computation time = 40.84281299999759ms
# outer_product = [[    0     0     0 ...     0     0     0]
#  [  200   201   202 ...   397   398   399]
#  [  400   402   404 ...   794   796   798]
#  ...
#  [39400 39597 39794 ... 78209 78406 78603]
#  [39600 39798 39996 ... 78606 78804 79002]
#  [39800 39999 40198 ... 79003 79202 79401]]
#
# Computation time = 1.7607939999990663ms

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import time
import numpy
import array
a = array.array('i')
for i in range(50000):
  a.append(i);
b = array.array('i')
for i in range(50000, 100000):
  b.append(i)
vector = numpy.zeros((50000))
tic = time.process_time()
for i in range(len(a)):
  vector[i]= a[i]*b[i]
toc = time.process_time()
print("Element wise Product = "+ str(vector));
print("\nComputation time = "+str(1000*(toc - tic ))+"ms")
n_tic = time.process_time()
vector = numpy.multiply(a, b)
n_toc = time.process_time()
print("Element wise Product = "+str(vector));
print("\nComputation time = "+str(1000*(n_toc - n_tic ))+"ms")
# Out:
# Element wise Product = [0.00000000e+00 5.00010000e+04 1.00004000e+05 ... 4.99955001e+09
#  4.99970000e+09 4.99985000e+09]
#
# Computation time = 36.84599400000366ms
# Element wise Product = [        0     50001    100004 ... 704582713 704732708 704882705]
#
# Computation time = 0.46969399999596817ms

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df=pd.read_csv("temp.csv")
print(df)

# %%
import pandas as pd
df=pd.read_csv("temp.csv",index_col=['S.No'])   #Custom Index
print(df)

# %%
import pandas as pd
df = pd.read_csv("temp.csv", dtype={'Salary': np.float64})
print(df.dtypes)

# %%
import pandas as pd
df=pd.read_csv("temp.csv", names=['a', 'b', 'c','d','e'])   #header_names
print(df)

# %%
import pandas as pd
df=pd.read_csv("temp.csv", skiprows=2)   #Skiprows
print(df)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")  #Selecting a Single Column
first = data["Age"]
print(first)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")  #Selecting Multiple Columns
first = data[["Age", "College", "Salary"]]
print(first)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")  #Selecting a single row (using .loc[])
first = data.loc["Avery Bradley"]
second = data.loc["R.J. Hunter"]
print(first, "\n\n\n", second)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")
first = data.loc[["Avery Bradley", "R.J. Hunter"]]   #Selecting Mutiple Rows
print(first)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")     #Selecting 2 rows and 3 columns
first = data.loc[["Avery Bradley", "R.J. Hunter"],
      ["Team", "Number", "Position"]]
print(first)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")
first = data.loc[:, ["Team", "Number", "Position"]]   #Selecting all rows and some columns
print(first)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")   #selecting a single row
row2 = data.iloc[3]
print(row2)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")   #Selecting multiple rows
row2 = data.iloc [[3, 5, 7]]
print(row2)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")   #Selecting 2 rows and 2 columns
row2 = data.iloc [[3, 4], [1, 2]]
print(row2)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")   #Selecting all rows and some columns
row2 = data.iloc [:, [1, 2]]
print(row2)

# %%
import pandas as pd
data = pd.read_csv("nba.csv", index_col ="Name")   #Selecting a single row using .ix[] as .loc[]
first = data.ix["Avery Bradley"]
print(first)

# %%
import pandas as pd
arrays = ['Sohom','Suresh','kumkum','subrata']     #Creating multi-index from arrays
age= [10, 11, 12, 13]
marks=[90,92,23,64]
multi_index = pd.MultiIndex.from_arrays([arrays,age,marks], names=('names', 'age','marks'))
print(multi_index)
# Out:
# MultiIndex([(  'Sohom', 10, 90),
#             ( 'Suresh', 11, 92),
#             ( 'kumkum', 12, 23),
#             ('subrata', 13, 64)],
#            names=['names', 'age', 'marks'])

# %%
import pandas as pd
dict = {'name': ["Saikat", "Shrestha", "Sandi", "Abinash"],
        'Jobs': ["Software Developer", "System Engineer","Footballer", "Singer"],
'Annual Salary(L.P.A)': [12.4, 5.6, 9.3, 10]}       #Creating multi-index from DataFrame using Pandas
df = pd.DataFrame(dict)
print(df)
# Out:
#        name                Jobs  Annual Salary(L.P.A)
# 0    Saikat  Software Developer                  12.4
# 1  Shrestha     System Engineer                   5.6
# 2     Sandi          Footballer                   9.3
# 3   Abinash              Singer                  10.0

# %%
pd.MultiIndex.from_frame(df)
# Out:
# MultiIndex([(100.0, 30.0,  nan),
#             ( 90.0, 45.0, 40.0),
#             (  nan, 56.0, 80.0),
#             ( 95.0,  nan, 98.0)],
#            names=['First Score', 'Second Score', 'Third Score'])

# %%
import pandas as pd
data = {
'series': ['Peaky blinders', 'Sherlock', 'The crown', 'Queens Gambit', 'Friends'],
'Ratings': [4.5, 5, 3.9, 4.2, 5],
'Date': [2013, 2010, 2016, 2020, 1994]       #Using DataFrame.set_index([col1,col2,..])
}
df = pd.DataFrame(data)
df.set_index(["series", "Ratings"], inplace=True, append=True, drop=False)
print(df)
# Out:
#                                   series  Ratings  Date
#   series         Ratings
# 0 Peaky blinders 4.5      Peaky blinders      4.5  2013
# 1 Sherlock       5.0            Sherlock      5.0  2010
# 2 The crown      3.9           The crown      3.9  2016
# 3 Queens Gambit  4.2       Queens Gambit      4.2  2020
# 4 Friends        5.0             Friends      5.0  1994

# %%
print(df.index)
# Out:
# MultiIndex([(0, 'Peaky blinders', 4.5),
#             (1,       'Sherlock', 5.0),
#             (2,      'The crown', 3.9),
#             (3,  'Queens Gambit', 4.2),
#             (4,        'Friends', 5.0)],
#            names=[None, 'series', 'Ratings'])

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
data = ['red', 'blue', 'green', 'red', 'blue']
categorical_data = pd.Categorical(data)
print(categorical_data)
# Out:
# ['red', 'blue', 'green', 'red', 'blue']
# Categories (3, object): ['blue', 'green', 'red']

# %%
import pandas as pd
data = ['red', 'blue', 'green', 'red', 'blue']   #Convert Pandas Series to Categorical Series
series1 = pd.Series(data)
categorical_s = series1.astype('category')
print(categorical_s)
# Out:
# 0      red
# 1     blue
# 2    green
# 3      red
# 4     blue
# dtype: category
# Categories (3, object): ['blue', 'green', 'red']

# %%
import pandas as pd       #Integer Data
s = pd.Series([1, 2, None], dtype="Int64")
s_plus_one = s + 1 # Adds 1 to each element in the series
comparison = s == 1 # Checks if each element in the series is equal to 1
print(s_plus_one)
print(comparison)
# Out:
# 0       2
# 1       3
# 2    <NA>
# dtype: Int64
# 0     True
# 1    False
# 2     <NA>
# dtype: boolean

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
s=pd.Series([80,81,75])
print(s.pct_change())
# Out:
# 0         NaN
# 1    0.012500
# 2   -0.074074
# dtype: float64

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame({
    '2019':[1869950,32586265],
    '2018':[1600923,42912316],
    '2017':[1471819,42403351]},
     index=['GOOG','APPL'])
df.pct_change(axis='columns')
# Out:
#       2019      2018      2017
# GOOG   NaN -0.143869 -0.080643
# APPL   NaN  0.316884 -0.011861

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
from sklearn import datasets
#Load IRIS dataset
iris=datasets.load_iris()
#Create dataframe
df=pd.DataFrame(iris.data,
columns=["sepal_length","sepal_width","petal_length","petal_width"])
df["class"]=iris.target
#Calculate covariance
df.iloc[:,0:4].cov()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
from sklearn import datasets
# Load IRIS dataset
iris = datasets.load_iris()
# Create dataframe from IRIS dataset
df = pd.DataFrame(iris.data, columns=["sepal_length","sepal_width","petal_length","petal_width"])
df["class"] = iris.target
# Calculate pairwise correlation between different columns
df.iloc[:,0:4].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
from sklearn import datasets
# Load IRIS dataset
iris= datasets.load_iris()
# Create dataframe from IRIS dataset
df= pd.DataFrame(iris.data, columns=["sepal_length","sepal_width","petal_length","petal_width"])
df["class"]= iris.target
# Calculate variance for different columns
df.iloc[:,0:4].var()
# Out:
# sepal_length    0.685694
# sepal_width     0.189979
# petal_length    3.116278
# petal_width     0.581006
# dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(data={'Animal': ['lion', 'fox', 'cow',
                                   'spider', 'snake'],
                        'Number_legs': [4, 4, 4, 8, np.nan]})
df = pd.DataFrame(data={'Animal': ['lion', 'fox', 'cow',
                 'spider', 'snake'], 'Number_legs': [4, 4, 4, 8, np.nan]})
df['default_rank'] = df['Number_legs'].rank()
df['max_rank'] = df['Number_legs'].rank(method='max')
df['NA_bottom'] = df['Number_legs'].rank(na_option='bottom')
df['pct_rank'] = df['Number_legs'].rank(pct=True)
df = pd.DataFrame(data={'Animal': ['fox', 'Kangaroo', 'deer','spider', 'snake'],'Number_legs': [4, 2, 4, 8, np.nan]})
df['default_rank'] = df['Number_legs'].rank()
df['max_rank'] = df['Number_legs'].rank(method='max')
df['NA_bottom'] = df['Number_legs'].rank(na_option='bottom')
df['pct_rank'] = df['Number_legs'].rank(pct=True)
print(df)
# Out:
#      Animal  Number_legs  default_rank  max_rank  NA_bottom  pct_rank
# 0       fox          4.0           2.5       3.0        2.5     0.625
# 1  Kangaroo          2.0           1.0       1.0        1.0     0.250
# 2      deer          4.0           2.5       3.0        2.5     0.625
# 3    spider          8.0           4.0       4.0        4.0     1.000
# 4     snake          NaN           NaN       NaN        5.0       NaN

# %%
mean = dataset['Age'].mean()            #Mean
print(mean)

# %%
median = dataset['Fare'].median()       #Median
print(median)

# %%
mode = dataset['Sex'].mode()            #Mode
print(mode)

# %%
count = dataset['Ticket'].count()       #Count
print(count)

# %%
std = dataset['Fare'].std()             #Standard Deviation
print(std)

# %%
maxValue = dataset['Age'].max()         #Max
print(maxValue)

# %%
minValue = dataset['Fare'].min()        #Min
print(minValue)

# %%
dataset.describe()                      #Describe

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd         #Rolling Window
s= pd.Series(range(5), index=pd.date_range('2020-01-01', periods=5, freq='1D'))
s.rolling(window='2D').sum()
# Out:
# 2020-01-01    0.0
# 2020-01-02    1.0
# 2020-01-03    3.0
# 2020-01-04    5.0
# 2020-01-05    7.0
# Freq: D, dtype: float64

# %%
import pandas as pd
df = pd.DataFrame({'A': ['a', 'b', 'a', 'b', 'a'], 'B': range(5)})   #Expanding Window
df.groupby('A').expanding().sum()
# Out:
#        B
# A
# a 0  0.0
#   2  2.0
#   4  6.0
# b 1  1.0
#   3  4.0

# %%
import pandas as pd
import numpy as np
def weighted_mean(x):
  arr = np.ones((1, x.shape[1]))
  arr[:, :2] = (x[:, :2] * x[:, 2]).sum(axis=0) / x[:, 2].sum()   #Weighted Window
  return arr
df = pd.DataFrame([[1, 2, 0.6], [2, 3, 0.4], [3, 4, 0.2], [4, 5, 0.7]])
df.rolling(2, method="table", min_periods=0).apply(weighted_mean, raw=True, engine="numba")
# Out:
#           0         1    2
# 0  1.000000  2.000000  1.0
# 1  1.800000  2.000000  1.0
# 2  3.333333  2.333333  1.0
# 3  1.555556  7.000000  1.0

# %%
import pandas as pd      #Exponentially Weighted Window
df = pd.DataFrame([[1, 2, 0.6], [2, 3, 0.4], [3, 4, 0.2], [4, 5, 0.7]])
df.ewm(0.5).mean()
# Out:
#           0         1         2
# 0  1.000000  2.000000  0.600000
# 1  1.750000  2.750000  0.450000
# 2  2.615385  3.615385  0.276923
# 3  3.550000  4.550000  0.562500

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
